# %% [markdown]
# True and False

# %%
x == y
x is y:

# %% [markdown]
# Logical Operators

# %%
a and b
a or b
not a

# %% [markdown]
# Conditional Expressions

# %%
x = true_value if condition else false_value
